# %%
print(3+2)
# Out:
# 5

# %%
print(3-2)
# Out:
# 1

# %%
print(3*2)
# Out:
# 6

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3%2)
# Out:
# 1

# %%
print(3**2)
# Out:
# 9

# %%
print(3//2)
# Out:
# 1

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(3.2))
# Out:
# <class 'float'>

# %%
print(type(1+3j))
# Out:
# <class 'complex'>

# %%
print(type('Asna'))
# Out:
# <class 'str'>

# %%
print(type ({'name':'asna'}))
# Out:
# <class 'dict'>

# %%
print(type([1,2,2]))
# Out:
# <class 'list'>

# %%
print(type({1,2,3}))
# Out:
# <class 'set'>

# %%
print(type((1.2,2.3)))
# Out:
# <class 'tuple'>

# %%
print(type(1>=2))
# Out:
# <class 'bool'>

# %%
print(1>=2)
# Out:
# False
